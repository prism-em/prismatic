# %% [markdown]
# # Jupyter Notebooks
# <img src="img/logo.png" alt="Prismatic logo" style="width: 250px;"/>

# %%
import os
print(os.listdir(os.getcwd()))
# %pylab inline
pylab.rcParams['figure.figsize'] = (20, 12)
# Out:
# ['.ipynb_checkpoints', 'debug_scompact.mrc', 'debug_scompact_i.mrc', 'debug_scompact_r.mrc', 'Demo.ipynb', 'img', 'output.mrc', 'qxaReduce.mrc', 'qxaShift.mrc', 'thickness_scan.py', 'thickness_scan1.mrc', 'thickness_scan10.mrc', 'thickness_scan11.mrc', 'thickness_scan12.mrc', 'thickness_scan13.mrc', 'thickness_scan14.mrc', 'thickness_scan15.mrc', 'thickness_scan16.mrc', 'thickness_scan2.mrc', 'thickness_scan3.mrc', 'thickness_scan4.mrc', 'thickness_scan5.mrc', 'thickness_scan6.mrc', 'thickness_scan7.mrc', 'thickness_scan8.mrc', 'thickness_scan9.mrc', 'untitled']
# Populating the interactive namespace from numpy and matplotlib

# %%
# %load thickness_scan.py
# This script calculates multiple images using a unit cell tiled varying numbers of times in Z. 
# This type of simulation is useful for determining the true thickness of a sample from experimental images

import pyprismatic as pr
import numpy as np
import matplotlib.pyplot as plt

base_output_name = "thickness_scan"
base_output_ext  = ".mrc"
atom_filename    = "/Users/ajpryor/Documents/MATLAB/multislice/PRISM/SI100.XYZ"
tileX=tileY=3
meta = pr.Metadata(filenameAtoms=atom_filename, tileX=tileX, tileY=tileY)
output_filenames=[]
f, ax = plt.subplots(4, 4)
plt.tight_layout()
plt.suptitle("Bright Field (0-10 mrad) PRISM images for SI100 of varying thicknesses")
ax = ax.ravel()
for i,tileZ in enumerate(range(1,17)):
#     print("i, tileZ", i, tileZ)
    meta.tileZ = tileZ
    meta.filenameOutput = base_output_name + str(tileZ) + base_output_ext
#     print( meta.filenameOutput)
    output_filenames.extend([meta.filenameOutput])
    meta.go()
    stack = pr.fileio.readMRC(meta.filenameOutput)
    img = np.squeeze(np.sum(stack[:, :, :10], axis=2))
    ax[i].imshow(img)
    ax[i].set_title("Thicknesss: {:.2f}$\AA$".format((i + 1) * 5.43))
    ax[i].set_yticklabels([])
    ax[i].set_xticklabels([])
#     plt.draw()
#     plt.pause(0.0001)
plt.show()

# %% [markdown]
# ## A sample header
#
# Lorem Ipsum is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book. It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged. It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum

# %% [markdown]
# ---

# %% [markdown]
# ## Embedding equations
#
# You can typeset equations with LaTex inline $a=\sqrt{b^2+c^2}$
#
#
# Or alternative you can format fully
#   $$\psi_{p+1}(\vec{r}) =  \psi_p(\vec{r})
#     \exp \left[i
#      \sigma V_p^{\rm{2D}}(\vec{r})
#     \right]$$

# %% [markdown]
# ---

# %% [markdown]
# ### You can also add bullet points
#
# * or you could number
# * them
#
#
# 1. and describe
# 2. each of them
# 3. like this

# %% [markdown]
# ---

# %% [markdown]
# ### Code formatting
#
# I could write some Python code
# ~~~ python
# import pyprismatic as pr
# import numpy as np
# import matplotlib.pyplot as plt
#
# base_output_name = "thickness_scan"
# base_output_ext  = ".mrc"
# atom_filename    = "/Users/ajpryor/Documents/MATLAB/multislice/PRISM/SI100.XYZ"
# tileX=tileY=3
# ~~~
#
# As easily as C++
#
# ~~~ c++
# using namespace std;
# int main(int argc, const char** argv) {
# 	Prismatic::Metadata<PRISMATIC_FLOAT_PRECISION> meta;
#
# 	// parse command line options
# 	if (!Prismatic::parseInputs(meta, argc, &argv))return 1;
#
# 	// print metadata
#     meta.toString();
#
# 	// configure simulation behavior
# 	Prismatic::configure(meta);
#
# 	// execute simulation
# 	Prismatic::execute_plan(meta);
# 	return 0;
# }
# ~~~
#
# Or even MATLAB
#
# ~~~ MATLAB
# for i = 1:5
#     d = d + i;
# end
# ~~~

# %% [markdown]
# ### Executing code

# %%
import numpy as np
import matplotlib.pyplot as plt
pylab.rcParams['figure.figsize'] = (10, 6)
n = 32
img = np.random.rand(n,n)
plt.figure()
plt.imshow(img, interpolation="nearest")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-244a75d0838f> in <module>()
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 pylab.rcParams['figure.figsize'] = (10, 6)
#       4 n = 32
#       5 img = np.random.rand(n,n)
#
# NameError: name 'pylab' is not defined
